# %%
preflightComponents85=<|
"ModelHash"->SameQ[modelHash79A,expectedFrozenModelHash79A],
"MinimalKernelHash"->SameQ[minimalKernelDefinitionTextHash85,expectedMinimalKernelDefinitionTextHash85],
"CanonicalizerHash"->SameQ[canonicalizerImplementationHash79B,expectedCanonicalizerHash85],
"StableArchitectureHash"->SameQ[stableFrozenArchitectureHash85,expectedStableFrozenArchitectureHash85],
"InterventionPrimitiveHash"->SameQ[interventionImplementationHash82,expectedInterventionHash85],
"CandidateAssociation"->AssociationQ[frozenCandidate83B],
"CandidateHash"->SameQ[candidateHashLoaded85,expectedCandidateHash85],
"BaseFrozenModelHash"->SameQ[frozenCandidate83B["BaseFrozenModelHash"],expectedFrozenModelHash79A],
"EncoderParams"->SameQ[frozenCandidate83B["EncoderParams"],frozen75D["Params"]],
"Representation"->SameQ[frozenCandidate83B["Representation"],"KExactRole"],
"K"->SameQ[frozenCandidate83B["K"],19],
"PolicyLength"->SameQ[Length[frozenCandidate83B["Policy"]],26],
"DevelopmentScore"->SameQ[frozenCandidate83B["DevelopmentScore"],264],
"ExactNodeRoleUsed"->TrueQ[frozenCandidate83B["ExactNodeRoleUsed"]],
"FrozenBeforeS84"->TrueQ[frozenCandidate83B["FrozenBeforeS84"]]
|>;
Dataset[{preflightComponents85}]
