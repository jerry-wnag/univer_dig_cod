# %% [markdown]
# # TCCT S94A — Modulus Feasibility Audit Result
#
# This viewer reads the completed audit certificate only. It does not rerun S94 or modify the model.

# %%
auditPath94A="E:/engine_wolf/TCCT_S94A_ModulusFeasibilityAudit.json";
audit94A=Quiet@Check[Import[auditPath94A,"RawJSON"],$Failed];
If[!AssociationQ[audit94A],
  Style["S94A audit certificate could not be loaded.",Red,14],
  Dataset[{KeyTake[audit94A,{
    "Stage","Name","AuditValidityPassed",
    "Position3RawZeroCount",
    "Position3CanBeRepairedByModulusAlone",
    "FrozenSupportedForwardCases",
    "PositionsWithAnyPerfectModulus2Through4096",
    "MinimumPerfectModulusByPosition",
    "FullVectorRetainsDistinguishingInformation",
    "OriginalFrozenModelChanged","CoreChanged",
    "DynamicModulusSelected","Outcome","SuggestedNextStage"
  }]}]
]
