# %% [markdown]
# # S86A read-only failure snapshot
# No cases are recomputed and no candidate is edited.

# %%
snapshot86A=<|
"BaselinePredictionCounts"->Counts[Lookup[baselineWorlds86,"Prediction"]],
"InterventionPredictionCounts"->Counts[Lookup[interventionWorlds86,"Prediction"]],
"ContinueTargetPredictionCounts"->Counts[Lookup[Select[blindWorlds86,SameQ[#["Target"],"Continue"]&],"Prediction"]],
"StopTargetPredictionCounts"->Counts[Lookup[Select[blindWorlds86,SameQ[#["Target"],"Stop"]&],"Prediction"]],
"BaselinePolicyHitCountDistribution"->Counts[Length/@Lookup[baselineWorlds86,"PolicyHitTokens"]],
"InterventionPolicyHitCountDistribution"->Counts[Length/@Lookup[interventionWorlds86,"PolicyHitTokens"]],
"IncorrectContinueWorlds"->Count[blindWorlds86,w_/;SameQ[w["Target"],"Continue"]&&!TrueQ[w["Correct"]]],
"IncorrectStopWorlds"->Count[blindWorlds86,w_/;SameQ[w["Target"],"Stop"]&&!TrueQ[w["Correct"]]],
"CandidateHashUnchanged"->SameQ[candidateHashBefore86,candidateHashAfter86],
"CoreHashUnchanged"->SameQ[coreHashBefore86,coreHashAfter86]
|>;
Dataset[{snapshot86A}]
